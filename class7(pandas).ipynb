# %%
import numpy as np
import pandas as pd

n1 = np.random.randint(50,100,size=(10))#大小10列內各五個
s1 = pd.Series(data = n1,index=[f'學生{i+1}' for i in range(10)])
display(s1*100)
display(s1.values)
display(s1.index)
# Out:
# 學生1     9800
# 學生2     6300
# 學生3     7900
# 學生4     5100
# 學生5     5000
# 學生6     6000
# 學生7     8400
# 學生8     5800
# 學生9     8700
# 學生10    9400
# dtype: int64
# array([98, 63, 79, 51, 50, 60, 84, 58, 87, 94])
# Index(['學生1', '學生2', '學生3', '學生4', '學生5', '學生6', '學生7', '學生8', '學生9', '學生10'], dtype='object')

# %%
import requests
import pandas as pd

# 設定time為獲取中文姓名100筆的倍數。time=3，就是300筆的意思。
times = 1
cnames = []
for x in range(times):
    url = 'http://www.richyli.com/name/index.asp'
    r = requests.get(url)
    r.encoding = 'big5'
    
    # 將網頁中的資料以分行的方式存成文字檔
    result = r.text.splitlines()
    
    # 114是中文姓名開始的列，找到最後一個「、」，設定成為字串的切片位置。
    char_index = result[114].rfind("、")
    temp = result[114][:char_index]
    
    # 將temp的100筆姓名新增到cnames中
    cnames.append(temp)

# 將每100筆姓名的list加一個「、」，再組合成字串存到my_names中
my_names = "、".join(str(x) for x in cnames)
print(my_names)
# Out:
# 白宗翰、陳國侑、林佳燕、李淑芬、張睿全、蕭祖蓁、林心怡、蔡于真、劉哲維、張惠珊、許韋廷、林心怡、周介英、林瑋婷、張馨軒、別水劭、王哲宇、李政白、陳欣紫、周仕洋、錢淑娟、戎思梅、楊雅愛、李晉琬、吳為君、姚世昌、沈仕財、蔡仕妮、楊佳玲、王冠宇、杜芳如、劉治�琚B王秀玲、宓亦珮、張志峰、黃俊康、朱柏帆、蔡志軒、陳子源、戴慈芝、陳湘婷、陳珍信、臧惠玲、鍾明毓、李育正、倪英春、葉維哲、邱怡靜、張凱泉、劉佳卿、李靜韋、林姿江、陳沛威、吳淳蓮、莊雅易、李虹良、黃心華、黃筱瑄、黃家銘、洪育儒、陳琳苓、鄭宣仁、黎明倫、朱偉誠、蔡美君、楊湘揚、柯韻婷、楊琬婷、趙佩珊、李安漢、黃雅娟、郭國駿、楊月愛、簡佳蓉、游尹妤、張其全、王克恩、蘇倫君、梁志銘、陸祐誠、林嘉雯、呂佳珠、詹玉梅、高家綺、夏美玲、劉美雅、戴維哲、陳文賢、謝碧萱、翁鎮宇、張家佳、林宏琇、陳彥佩、方振玲、王軒豪、劉玉婷、林致遠、廖淑玲、丁怡潔、裴伯旺

# %%
import requests
def getNames(num):
    times = 1
    cnames = []
    for x in range(times):
        url = 'http://www.richyli.com/name/index.asp'
        r = requests.get(url)
        r.encoding = 'big5'
        
        # 將網頁中的資料以分行的方式存成文字檔
        result = r.text.splitlines()
        
        # 114是中文姓名開始的列，找到最後一個「、」，設定成為字串的切片位置。
        char_index = result[114].rfind("、")
        temp = result[114][:char_index]
        
        # 將temp的100筆姓名新增到cnames中
        cnames.append(temp)
    print(type(cnames[0]))
    names = cnames[0].split('、')
    return names[:num]


names = getNames(100)
# Out:
# <class 'str'>

# %%
import numpy as np
import pandas as pd
'''
n2 = np.random.randint(50,100,size=(50,5))
dataFrame = pd.DataFrame(data=n2,
            index=names[:50],
            columns=["國文","英文","社會","地理","天文"]
            )
dataFrame
'''
n2 = np.random.randint(50,100,size=(50,5))
dataFrame = pd.DataFrame(data=n2,
             index=names[:50],
             columns=["國文","英文","數學","地理","歷史"]
             )
dataFrame
# Out:
#      國文  英文  數學  地理  歷史
# 王淑君  70  76  71  72  62
# 汪樂軍  79  84  59  86  75
# 吉平菁  96  72  50  76  62
# 洪明亮  57  64  53  88  75
# 郝綠珠  96  59  71  56  64
# 湛文馨  97  97  86  93  78
# 張秉信  68  70  64  84  61
# 林志智  83  93  72  54  51
# 王富恩  75  80  99  93  83
# 林益映  62  55  69  97  95
# 賴建合  94  61  92  95  52
# 蔡佳軍  94  85  77  74  55
# 張振儒  50  74  82  73  93
# 黃柏珮  52  59  52  73  89
# 蔡宗音  82  53  62  58  86
# 陳麗梅  91  80  52  74  92
# 吳佩琴  82  76  78  74  63
# 林皇光  53  66  53  71  84
# 周君旭  72  92  61  95  53
# 林冰亨  54  51  79  93  93
# 莊雅如  90  84  66  63  84
# 葉詩婷  51  96  59  57  93
# 王貞儀  50  69  52  80  80
# 張詩婷  99  87  69  54  67
# 黃秀誠  52  90  89  88  94
# 陳韋志  62  63  80  82  54
# 侯淑芬  55  94  51  72  99
# 陳佳茂  63  84  65  73  65
# 馮翊喬  61  82  71  64  56
# 楊舒慈  59  68  66  64  93
# 郭淑廷  60  86  59  75  74
# 陳國谷  59  79  55  89  62
# 林怡一  79  55  73  81  71
# 林瓊慧  52  52  79  64  68
# 曹雅惠  61  57  80  74  57
# 蔡政映  51  86  98  94  66
# 安欣怡  90  68  77  98  50
# 涂佳玲  67  94  83  54  86
# 黃俐佩  55  90  54  82  51
# 黃彥任  78  82  67  83  90
# 方翊仰  78  72  75  68  66
# 黃玄冰  61  61  76  77  83
# 梁吉麟  59  81  63  97  72
# 簡明慧  63  87  61  96  61
# 林宜博  62  85  89  79  89
# 郭國華  96  97  65  78  83
# 黃琪火  68  60  89  67  91
# 洪彥君  74  54  96  68  78
# 曹亭玫  52  73  88  53  83
# 朱軒興  52  65  71  69  64

# %%
dataFrame["國文"]
print(dataFrame[['歷史',"英文"]])

total = dataFrame["國文"] + dataFrame["英文"]+dataFrame["數學"]+dataFrame["地理"]+dataFrame["歷史"]
dataFrame["總分"] = total
dataFrame
# Out:
#      歷史  英文
# 王淑君  62  76
# 汪樂軍  75  84
# 吉平菁  62  72
# 洪明亮  75  64
# 郝綠珠  64  59
# 湛文馨  78  97
# 張秉信  61  70
# 林志智  51  93
# 王富恩  83  80
# 林益映  95  55
# 賴建合  52  61
# 蔡佳軍  55  85
 114是中文姓名開始的列，找到最後一個「、」，設定成為字串的切片位置。
        char_index = result[114].rfind("、")
        temp = result[114][:char_index]
        
        # 將temp的100筆姓名新增到cnames中
        cnames.append(temp)    
    return cnames


names = getNames()

# %%
#使用"、"符號,連結3個陣列元素
names_str = "、".join(names)
names_list = names_str.split("、") #有299筆的list
newLine_name = "\n".join(names_list)  #有換行符號的字串
print(newLine_name)
# Out:
# 黃素貞
# 陳佩蓉
# 姜宥淳
# 張佩穎
# 吳昭堯
# 林志男
# 蔡台仲
# 柯曉萍
# 黃建緯
# 王麗梅
# 王益山
# 陳佳穎
# 施芷軒
# 王香發
# 高祐湖
# 謝奕翔
# 林琇甫
# 鄧彥安
# 金俊穎
# 楊淑玲
# 賴怡雄
# 郭書淳
# 劉雅文
# 吳家瑋
# 陳慧珊
# 鄭凱諭
# 林逸喜
# 王博寧
# 顏惠茹
# 廖偉瑄
# 馮天�琚B張忠妮
# 林秀玲
# 闕姿穎
# 蔡靜宜
# 楊智育
# 劉柏宏
# 柳馨文
# 楊雅婷
# 楊昶花
# 張美惠
# 丁元蘋
# 陳建宏
# 潘心怡
# 王偉倫
# 許純毓
# 劉淑君
# 馮宜臻
# 馮邦宇
# 宋仁傑
# 林郁婷
# 黃詩珊
# 全肇安
# 謝姿蓉
# 陳建亨
# 傅惠婷
# 廖育菁
# 涂亮禮
# 彭婉婷
# 張昀喬
# 陸建成
# 許淑敏
# 陳銘蓁
# 馮乃芷
# 袁義嘉
# 蔡文智
# 蔡佳信
# 劉怡君
# 林曉琦
# 陳柏容
# 陳耿達
# 陳怡君
# 鄭宇蘋
# 黃聖迪
# 黃竹瑞
# 張映臻
# 許雅紹
# 鄧芳如
# 蔣于婷
# 申祖茹
# 張翰安
# 吳美仁
# 林靜宜
# 林怡一
# 陳揚駿
# 吳信宏
# 李柏文
# 鄧欣怡
# 黃倫夫
# 孫志穎
# 陳逸啟
# 李孝任
# 尤培丞
# 李冠廷
# 黃冠良
# 詹建緯
# 艾涵宣
# 張惟宏
# 璩永信
# 駱定菱
# 張淑琴
# 劉怡俊
# 黃乃添
# 賴宗翰
# 李俊弘
# 陳依云
# 張永淳
# 袁明軒
# 趙朝樺
# 張俞瑤
# 李宜來
# 王俊男
# 徐俊諺
# 鍾明婷
# 姚侑鴻
# 洪偉發
# 吳建良
# 林冠瑄
# 方志文
# 陳佳依
# 李佳蓉
# 林婉菁
# 陳冠軍
# 吳美海
# 劉怡和
# 盧雅婷
# 張美雲
# 陳宜秀
# 徐憶儒
# 王裕仁
# 劉泰瑋
# 廖佑霖
# 林書吉
# 林憲妤
# 周宇軒
# 陳俊芬
# 陳怡君
# 郭聿吉
# 吳瑋婷
# 林淑禾
# 林育意
# 高民行
# 林宜潔
# 李怡秀
# 曾淑源
# 陳峻豪
# 黃靜康
# 張依萍
# 陳姿婷
# 單敏苓
# 謝成麟
# 高東宣
# 蔡秉春
# 吳俊男
# 陳柏宸
# 陳思哲
# 楊雅君
# 林睿雯
# 周惠珠
# 陳威毓
# 蔡雅雯
# 吳雯辰
# 阮志豪
# 童毅孜
# 陳欣瑜
# 龔傑霖
# 袁廷白
# 陳立芬
# 蔡孝能
# 林建禾
# 懷松昕
# 張淑媛
# 王俊映
# 吳淑慧
# 宋佩樺
# 林紫豪
# 彭怡如
# 陳順瑜
# 李竹泰
# 陳珍伯
# 葉俊緯
# 程怡君
# 宋士幸
# 張志彬
# 林夢昕
# 王冠幸
# 林建紫
# 陳秋利
# 郭佳霖
# 黃建勳
# 陳芃均
# 李雅如
# 趙燦茂
# 陳秀慈
# 潘昶坤
# 陳信明
# 黃家綺
# 盧嘉慧
# 林宜弘
# 黃國諭
# 謝治君
# 謝晉廷
# 呂妤啟
# 鄭佳穎
# 王怡伶
# 吳艾禾
# 黃聖傑
# 張明平
# 林淑雪
# 宋俞辰
# 周佳蓉
# 簡駿天
# 林樂緯
# 吳俊宇
# 李文柏
# 李淳恭
# 郭志豪
# 張瑋婷
# 王旺杰
# 吳文青
# 馬宜臻
# 林姿泰
# 陳雅玲
# 簡宗翰
# 童韻如
# 戴文宏
# 蔣昱廷
# 黃子臻
# 汪毅亞
# 陳婉友
# 黃淑玲
# 侯靜愛
# 蔡佳華
# 陳合妮
# 張哲政
# 王冠倩
# 張美群
# 王振豪
# 簡智文
# 劉怡萍
# 劉佩珊
# 林又虹
# 楊康峰
# 陳慶依
# 李淑玲
# 郭虹智
# 王培倫
# 歐禮茵
# 金姵明
# 謝佩蓉
# 王惠麟
# 吳妍峰
# 倪佳珮
# 陳婷財
# 蔡水帆
# 林家奇
# 張雅萍
# 陳儒洋
# 劉函柏
# 陳奕豐
# 徐禮竹
# 葉怡君
# 吳麗芬
# 林俊豪
# 陳淑偉
# 江協花
# 黃剛玄
# 林登穎
# 林佳冰
# 郭佑維
# 張毓均
# 簡文君
# 吳杰士
# 林俊維
# 黃文賢
# 徐涵茵
# 李筠璇
# 王明淑
# 謝欣凌
# 邱智凱
# 蔡明翰
# 王筱芸
# 黃文劭
# 溫淳潔
# 張國華
# 曾典苓
# 顏惠全
# 謝昕峰
# 陳昭原
# 何柔玫
# 鄭宇芷
# 張雅慧
# 林宛雄
# 徐喬勳
# 黃詩祥
# 陳尹玄
# 張瑞娥
# 陸鈺婷
# 張曜宇
# 陳旻民

# %%
with open("names.csv",mode="w",newline="") as file:
    file.write(newLine_name)
