# %%
import requests
url = 'https://opendata.cwb.gov.tw/fileapi/v1/opendataapi/F-C0032-001?Authorization=rdec-key-123-45678-011121314&format=JSON'

respone = requests.get(url)
if respone.status_code == 200:
    print("下載成功")
# Out:
# 下載成功

# %%
display(str(respone.content))
# Out:
# 'b\'{\\n "cwbopendata": {\\n  "@xmlns": "urn:cwb:gov:tw:cwbcommon:0.1",\\n  "identifier": "a9513e4d-f1eb-59dd-33cd-f9e42ea5fd8b",\\n  "sender": "weather@cwb.gov.tw",\\n  "sent": "2023-08-12T03:30:03+08:00",\\n  "status": "Actual",\\n  "msgType": "Issue",\\n  "source": "MFC",\\n  "dataid": "C0032-001",\\n  "scope": "Public",\\n  "dataset": {\\n   "datasetInfo": {\\n    "datasetDescription": "\\xe4\\xb8\\x89\\xe5\\x8d\\x81\\xe5\\x85\\xad\\xe5\\xb0\\x8f\\xe6\\x99\\x82\\xe5\\xa4\\xa9\\xe6\\xb0\\xa3\\xe9\\xa0\\x90\\xe5\\xa0\\xb1",\\n    "issueTime": "2023-08-12T05:00:00+08:00",\\n    "update": "2023-08-12T03:30:03+08:00"\\n   },\\n   "location": [\\n    {\\n     "locationName": "\\xe8\\x87\\xba\\xe5\\x8c\\x97\\xe5\\xb8\\x82",\\n     "weatherElement": [\\n      {\\n       "elementName": "Wx",\\n       "time": [\\n        {\\n         "startTime": "2023-08-12T06:00:00+08:00",\\n         "endTime": "2023-08-12T18:00:00+08:00",\\n         "parameter": {\\n          "parameterName": "\\xe5\\xa
# ...

# %%
respone.text
# Out:
# '{\n "cwbopendata": {\n  "@xmlns": "urn:cwb:gov:tw:cwbcommon:0.1",\n  "identifier": "a9513e4d-f1eb-59dd-33cd-f9e42ea5fd8b",\n  "sender": "weather@cwb.gov.tw",\n  "sent": "2023-08-12T03:30:03+08:00",\n  "status": "Actual",\n  "msgType": "Issue",\n  "source": "MFC",\n  "dataid": "C0032-001",\n  "scope": "Public",\n  "dataset": {\n   "datasetInfo": {\n    "datasetDescription": "三十六小時天氣預報",\n    "issueTime": "2023-08-12T05:00:00+08:00",\n    "update": "2023-08-12T03:30:03+08:00"\n   },\n   "location": [\n    {\n     "locationName": "臺北市",\n     "weatherElement": [\n      {\n       "elementName": "Wx",\n       "time": [\n        {\n         "startTime": "2023-08-12T06:00:00+08:00",\n         "endTime": "2023-08-12T18:00:00+08:00",\n         "parameter": {\n          "parameterName": "多雲午後短暫雷陣雨",\n          "parameterValue": "22"\n         }\n        },\n        {\n         "startTime": "2023-08-12T18:00:00+08:00",\n         "endTime": "2023-08-13T06:00:00+08:00",\n         "parameter": {\
# ...

# %%
type(respone.json())
respone.json()
# Out:
# {'cwbopendata': {'@xmlns': 'urn:cwb:gov:tw:cwbcommon:0.1',
#   'identifier': 'a9513e4d-f1eb-59dd-33cd-f9e42ea5fd8b',
#   'sender': 'weather@cwb.gov.tw',
#   'sent': '2023-08-12T03:30:03+08:00',
#   'status': 'Actual',
#   'msgType': 'Issue',
#   'source': 'MFC',
#   'dataid': 'C0032-001',
#   'scope': 'Public',
#   'dataset': {'datasetInfo': {'datasetDescription': '三十六小時天氣預報',
#     'issueTime': '2023-08-12T05:00:00+08:00',
#     'update': '2023-08-12T03:30:03+08:00'},
#    'location': [{'locationName': '臺北市',
#      'weatherElement': [{'elementName': 'Wx',
#        'time': [{'startTime': '2023-08-12T06:00:00+08:00',
#          'endTime': '2023-08-12T18:00:00+08:00',
#          'parameter': {'parameterName': '多雲午後短暫雷陣雨', 'parameterValue': '22'}},
#         {'startTime': '2023-08-12T18:00:00+08:00',
#          'endTime': '2023-08-13T06:00:00+08:00',
#          'parameter': {'parameterName': '多雲短暫陣雨', 'parameterValue': '8'}},
#         {'startTime': '2023-08-13T06:00:00+08:00',
# ...
